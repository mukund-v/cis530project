# %%
# !pip install torch
# !pip install transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/a3/78/92cedda05552398352ed9784908b834ee32a0bd071a9b32de287327370b7/transformers-2.8.0-py3-none-any.whl (563kB)
#      |████████████████████████████████| 573kB 4.7MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.38.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.12.43)
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d1/3f/73c881ea4723e43c1e9acf317cf407fab3a278daab3a69c98dcac511c04f/tokenizers-0.5.2-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 14.9MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/98/2c/8df20f3ac6c22ac224fff307ebc102818206c53fc454ecd37d8ac2060df5/sentencepiece-0.1.86-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 37.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.21.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/99/50/93509f906a40bffd7d175f97fd75ea328ad9bd91f48f59c4bd084c94a25e/sacremoses-0.0.41.tar.gz (883kB)
#      |████████████████████████████████| 890kB 59.8MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.9.5)
# Requirement already satisfied: botocore<1.16.0,>=1.15.43 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (1.15.43)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.8)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.43->boto3->transformers) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.43->boto3->transformers) (0.15.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.41-cp36-none-any.whl size=893334 sha256=9a9711415ae8a415761ed9823fed2410015896460d670d5a1d29d3286f98d8d5
#   Stored in directory: /root/.cache/pip/wheels/22/5a/d4/b020a81249de7dc63758a34222feaa668dbe8ebfe9170cc9b1
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.41 sentencepiece-0.1.86 tokenizers-0.5.2 transformers-2.8.0

# %%
import torch
from transformers import squad_convert_examples_to_features
from transformers.data.processors.squad import SquadResult, SquadV2Processor
from transformers import BertModel, BertConfig, BertTokenizer

# %%
device = torch.device('cuda')
feature_processor = SquadV2Processor()
examples = feature_processor.get_dev_examples('/content/drive/My Drive/cis530project/cis530project/data')
# Out:
# 100%|██████████| 35/35 [00:04<00:00,  8.71it/s]
# HBox(children=(IntProgress(value=0, description='Downloading', max=231508, style=ProgressStyle(description_wid…

# %% [markdown]
# # BERT Model

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
from torch import nn
from transformers import BertModel, BertConfig, BertTokenizer

class BERT_SQUAD(nn.Module):
    def __init__(self):
        super(BERT_SQUAD, self).__init__()

        self.bert_model = BertModel.from_pretrained('bert-base-uncased')

        self.fc_layers = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        )

        self.criterion = nn.CrossEntropyLoss()

        #self.softmax



    def forward(self, c_q_pairs, attention_mask, token_type_ids, start_indices, end_indices):

        bert_encoded = self.bert_model(
            input_ids=c_q_pairs,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        start_indices = (start_indices).clamp(0, start_outputs.shape[1]-1)
        end_indices = (end_indices).clamp(0, start_outputs.shape[1]-1)

        start_loss = self.criterion(start_outputs, start_indices)
        end_loss = self.criterion(end_outputs, end_indices)

        return 2*start_loss + end_loss


    def predict(self, c_q_pairs, attention_mask, token_type_ids):
        bert_encoded = self.bert_model(
            input_ids=c_q_pairs,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        starts, s_ind = start_outputs.max(1)
        ends, e_ind = end_outputs.max(1)


        answers = []
        for i in range(start_outputs.shape[0]):
            start = s_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            end = e_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            answers.append([start, end])
        return answers

# %%
bs1 = BERT_SQUAD()
bs1.load_state_dict(torch.load('/content/drive/My Drive/cis530project/bert-squad.pt'))
# Out:
# <All keys matched successfully>

# %%
features, dataset = squad_convert_examples_to_features(
    examples=examples,
    tokenizer=tokenizer,
    max_seq_length=512,
    doc_stride=128,
    max_query_length=128,
    is_training=False,
    return_dataset='pt',
    threads=1
)
# Out:
# convert squad examples to features:   0%|          | 0/11873 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/11873 [00:00<54:54,  3.60it/s]
#
# convert squad examples to features:   0%|          | 33/11873 [00:00<38:41,  5.10it/s]
#
# convert squad examples to features:   1%|          | 65/11873 [00:00<27:27,  7.17it/s]
#
# convert squad examples to features:   1%|          | 97/11873 [00:00<19:34, 10.02it/s]
#
# convert squad examples to features:   1%|          | 129/11873 [00:01<13:59, 14.00it/s]
#
# convert squad examples to features:   1%|▏         | 161/11873 [00:01<10:01, 19.48it/s]
#
# convert squad examples to features:   2%|▏         | 193/11873 [00:01<07:18, 26.64it/s]
#
# convert squad examples to features:   2%|▏         | 225/11873 [00:01<05:27, 35.57it/s]
#
# convert squad examples to features:   2%|▏         | 257/11873 [00:01<04:04, 47.45it/s]
#
# convert squad examples to features:   2%|▏         | 289/11873 [00:01<03:12, 60.03it/s]
#
# convert squad examples to features:   3%|▎         | 321/11873 [00:02<02:35, 74.17it/s]
#
# convert squad examples to features:   3%|▎         | 353/11873 [00:02<02:05, 91.70it/s]
#
# convert squad examples to features:   3%|▎         | 385/11873 [00:02<01:45, 108.55it/s]
#
# convert squad examples to features:   4%|▎         | 417/11873 [00:02<01:31, 125.76it/s]
#
# convert squad examples to features:   4%|▍         | 449/11873 [00:02<01:21, 140.45it/s]
#
# convert squad examples to features:   4%|▍         | 481/11873 [00:03<01:18, 145.90it/s]
#
# convert squad examples to features:   4%|▍         | 513/11873 [00:03<01:16, 148.32it/s]
#
# convert squad examples to features:   5%|▍         | 545/11873 [00:03<01:13, 153.67it/s]
#
# convert squad examples to features:   5%|▍         | 577/11873 [00:03<01:05, 171.48it/s]
#
# convert squad examples to features:   5%|▌         | 609/11873 [00:03<01:00, 186.11it/s]
#
# convert squad examples to features:   5%|▌         | 641/11873 [00:03<00:59, 190.01it/s]
#
# convert squad examples to features:   6%|▌         | 673/11873 [00:04<01:00, 185.41it/s]
#
# convert squad examples to features:   6%|▌         | 705/11873 [00:04<01:02, 178.60it/s]
#
# convert squad examples to features:   6%|▌         | 737/11873 [00:04<01:06, 166.55it/s]
#
# convert squad examples to features:   6%|▋         | 769/11873 [00:04<00:59, 185.67it/s]
#
# convert squad examples to features:   7%|▋         | 801/11873 [00:04<00:58, 190.34it/s]
#
# convert squad examples to features:   7%|▋         | 833/11873 [00:04<00:53, 206.87it/s]
#
# convert squad examples to features:   7%|▋         | 865/11873 [00:04<00:49, 223.99it/s]
#
# convert squad examples to features:   8%|▊         | 897/11873 [00:05<00:48, 226.51it/s]
#
# convert squad examples to features:   8%|▊         | 929/11873 [00:05<00:44, 247.71it/s]
#
# convert squad examples to features:   8%|▊         | 961/11873 [00:05<00:53, 204.68it/s]
#
# convert squad examples to features:   8%|▊         | 993/11873 [00:05<00:56, 192.12it/s]
#
# convert squad examples to features:   9%|▊         | 1025/11873 [00:05<00:59, 181.62it/s]
#
# convert squad examples to features:   9%|▉         | 1057/11873 [00:06<01:01, 174.51it/s]
#
# convert squad examples to features:   9%|▉         | 1089/11873 [00:06<01:07, 159.29it/s]
#
# convert squad examples to features:   9%|▉         | 1121/11873 [00:06<01:07, 160.11it/s]
#
# convert squad examples to features:  10%|▉         | 1153/11873 [00:06<01:07, 159.72it/s]
#
# convert squad examples to features:  10%|▉         | 1185/11873 [00:06<01:03, 167.42it/s]
#
# convert squad examples to features:  10%|█         | 1217/11873 [00:07<01:06, 160.46it/s]
#
# convert squad examples to features:  11%|█         | 1249/11873 [00:07<01:06, 160.89it/s]
#
# convert squad examples to features:  11%|█         | 1281/11873 [00:07<01:04, 163.38it/s]
#
# convert squad examples to features:  11%|█         | 1313/11873 [00:07<01:06, 159.71it/s]
#
# convert squad examples to features:  11%|█▏        | 1345/11873 [00:07<01:03, 166.09it/s]
#
# convert squad examples to features:  12%|█▏        | 1377/11873 [00:07<00:59, 175.53it/s]
#
# convert squad examples to features:  12%|█▏        | 1409/11873 [00:08<01:05, 160.86it/s]
#
# convert squad examples to features:  12%|█▏        | 1441/11873 [00:08<01:10, 147.65it/s]
#
# convert squad examples to features:  12%|█▏        | 1473/11873 [00:08<01:07, 154.47it/s]
#
# convert squad examples to features:  13%|█▎        | 1505/11873 [00:08<01:05, 159.38it/s]
#
# convert squad examples to features:  13%|█▎        | 1537/11873 [00:09<01:07, 154.00it/s]
#
# convert squad examples to features:  13%|█▎        | 1569/11873 [00:09<01:05, 158.15it/s]
#
# convert squad examples to features:  13%|█▎        | 1601/11873 [00:09<01:09, 147.36it/s]
#
# convert squad examples to features:  14%|█▍        | 1633/11873 [00:09<01:08, 150.08it/s]
#
# convert squad examples to features:  14%|█▍        | 1665/11873 [00:10<01:16, 133.79it/s]
#
# convert squad examples to features:  14%|█▍        | 1697/11873 [00:10<01:10, 145.17it/s]
#
# convert squad examples to features:  15%|█▍        | 1729/11873 [00:10<01:11, 142.63it/s]
#
# convert squad examples to features:  15%|█▍        | 1761/11873 [00:10<01:14, 136.53it/s]
#
# convert squad examples to features:  15%|█▌        | 1793/11873 [00:10<01:15, 133.95it/s]
#
# convert squad examples to features:  15%|█▌        | 1825/11873 [00:11<01:10, 142.95it/s]
#
# convert squad examples to features:  16%|█▌        | 1857/11873 [00:11<01:13, 137.13it/s]
#
# convert squad examples to features:  16%|█▌        | 1889/11873 [00:11<01:09, 144.52it/s]
#
# convert squad examples to features:  16%|█▌        | 1921/11873 [00:11<01:06, 149.27it/s]
#
# convert squad examples to features:  16%|█▋        | 1953/11873 [00:11<01:07, 147.75it/s]
#
# convert squad examples to features:  17%|█▋        | 1985/11873 [00:12<01:02, 157.00it/s]
#
# convert squad examples to features:  17%|█▋        | 2017/11873 [00:12<01:03, 154.19it/s]
#
# convert squad examples to features:  17%|█▋        | 2049/11873 [00:12<01:03, 155.41it/s]
#
# convert squad examples to features:  18%|█▊        | 2081/11873 [00:12<01:03, 154.81it/s]
#
# convert squad examples to features:  18%|█▊        | 2113/11873 [00:13<01:04, 150.32it/s]
#
# convert squad examples to features:  18%|█▊        | 2145/11873 [00:13<01:10, 137.51it/s]
#
# convert squad examples to features:  18%|█▊        | 2177/11873 [00:13<01:06, 146.34it/s]
#
# convert squad examples to features:  19%|█▊        | 2209/11873 [00:13<01:04, 149.06it/s]
#
# convert squad examples to features:  19%|█▉        | 2241/11873 [00:13<01:04, 148.75it/s]
#
# convert squad examples to features:  19%|█▉        | 2273/11873 [00:14<01:09, 138.24it/s]
#
# convert squad examples to features:  19%|█▉        | 2305/11873 [00:14<01:06, 143.72it/s]
#
# convert squad examples to features:  20%|█▉        | 2337/11873 [00:14<01:01, 154.57it/s]
#
# convert squad examples to features:  20%|█▉        | 2369/11873 [00:14<01:02, 151.78it/s]
#
# convert squad examples to features:  20%|██        | 2401/11873 [00:15<01:06, 143.49it/s]
#
# convert squad examples to features:  20%|██        | 2433/11873 [00:15<01:06, 142.02it/s]
#
# convert squad examples to features:  21%|██        | 2465/11873 [00:15<01:06, 140.75it/s]
#
# convert squad examples to features:  21%|██        | 2497/11873 [00:15<01:05, 143.50it/s]
#
# convert squad examples to features:  21%|██▏       | 2529/11873 [00:15<01:01, 150.98it/s]
#
# convert squad examples to features:  22%|██▏       | 2561/11873 [00:16<01:02, 149.02it/s]
#
# convert squad examples to features:  22%|██▏       | 2593/11873 [00:16<00:59, 155.48it/s]
#
# convert squad examples to features:  22%|██▏       | 2625/11873 [00:16<00:59, 155.12it/s]
#
# convert squad examples to features:  22%|██▏       | 2657/11873 [00:16<00:57, 160.17it/s]
#
# convert squad examples to features:  23%|██▎       | 2689/11873 [00:16<00:57, 159.02it/s]
#
# convert squad examples to features:  23%|██▎       | 2721/11873 [00:17<01:00, 152.31it/s]
#
# convert squad examples to features:  23%|██▎       | 2753/11873 [00:17<01:03, 144.51it/s]
#
# convert squad examples to features:  23%|██▎       | 2785/11873 [00:17<00:58, 155.48it/s]
#
# convert squad examples to features:  24%|██▎       | 2817/11873 [00:17<00:54, 166.88it/s]
#
# convert squad examples to features:  24%|██▍       | 2849/11873 [00:17<00:57, 156.96it/s]
#
# convert squad examples to features:  24%|██▍       | 2881/11873 [00:18<01:02, 142.85it/s]
#
# convert squad examples to features:  25%|██▍       | 2913/11873 [00:18<01:02, 144.51it/s]
#
# convert squad examples to features:  25%|██▍       | 2945/11873 [00:18<00:59, 150.82it/s]
#
# convert squad examples to features:  25%|██▌       | 2977/11873 [00:19<01:18, 112.88it/s]
#
# convert squad examples to features:  25%|██▌       | 3009/11873 [00:19<01:19, 112.12it/s]
#
# convert squad examples to features:  26%|██▌       | 3041/11873 [00:19<01:29, 98.58it/s]
#
# convert squad examples to features:  26%|██▌       | 3073/11873 [00:20<01:40, 87.49it/s]
#
# convert squad examples to features:  26%|██▌       | 3105/11873 [00:20<02:01, 72.27it/s]
#
# convert squad examples to features:  89%|████████▊ | 10529/11873 [01:17<00:10, 123.66it/s]
#
# convert squad examples to features:  89%|████████▉ | 10561/11873 [01:17<00:10, 120.38it/s]
#
# convert squad examples to features:  89%|████████▉ | 10593/11873 [01:17<00:09, 128.58it/s]
#
# convert squad examples to features:  89%|████████▉ | 10625/11873 [01:17<00:10, 116.09it/s]
#
# convert squad examples to features:  90%|████████▉ | 10657/11873 [01:18<00:09, 125.96it/s]
#
# convert squad examples to features:  90%|█████████ | 10689/11873 [01:18<00:09, 131.12it/s]
#
# convert squad examples to features:  90%|█████████ | 10721/11873 [01:18<00:08, 135.04it/s]
#
# convert squad examples to features:  91%|█████████ | 10753/11873 [01:18<00:08, 135.04it/s]
#
# convert squad examples to features:  91%|█████████ | 10785/11873 [01:19<00:08, 135.42it/s]
#
# convert squad examples to features:  91%|█████████ | 10817/11873 [01:19<00:08, 121.23it/s]
#
# convert squad examples to features:  91%|█████████▏| 10849/11873 [01:19<00:08, 127.67it/s]
#
# convert squad examples to features:  92%|█████████▏| 10881/11873 [01:19<00:07, 130.57it/s]
#
# convert squad examples to features:  92%|█████████▏| 10913/11873 [01:20<00:07, 130.03it/s]
#
# convert squad examples to features:  92%|█████████▏| 10945/11873 [01:20<00:06, 137.58it/s]
#
# convert squad examples to features:  92%|█████████▏| 10977/11873 [01:20<00:06, 148.41it/s]
#
# convert squad examples to features:  93%|█████████▎| 11009/11873 [01:20<00:05, 156.86it/s]
#
# convert squad examples to features:  93%|█████████▎| 11041/11873 [01:20<00:05, 160.57it/s]
#
# convert squad examples to features:  93%|█████████▎| 11073/11873 [01:20<00:04, 162.88it/s]
#
# convert squad examples to features:  94%|█████████▎| 11105/11873 [01:21<00:04, 156.61it/s]
#
# convert squad examples to features:  94%|█████████▍| 11137/11873 [01:21<00:04, 159.04it/s]
#
# convert squad examples to features:  94%|█████████▍| 11169/11873 [01:21<00:04, 153.65it/s]
#
# convert squad examples to features:  94%|█████████▍| 11201/11873 [01:21<00:04, 148.68it/s]
#
# convert squad examples to features:  95%|█████████▍| 11233/11873 [01:22<00:04, 137.36it/s]
#
# convert squad examples to features:  95%|█████████▍| 11265/11873 [01:22<00:04, 147.02it/s]
#
# convert squad examples to features:  95%|█████████▌| 11297/11873 [01:22<00:03, 147.66it/s]
#
# convert squad examples to features:  95%|█████████▌| 11329/11873 [01:22<00:03, 142.07it/s]
#
# convert squad examples to features:  96%|█████████▌| 11361/11873 [01:22<00:03, 143.76it/s]
#
# convert squad examples to features:  96%|█████████▌| 11393/11873 [01:23<00:03, 139.46it/s]
#
# convert squad examples to features:  96%|█████████▌| 11425/11873 [01:23<00:03, 148.47it/s]
#
# convert squad examples to features:  96%|█████████▋| 11457/11873 [01:23<00:03, 136.59it/s]
#
# convert squad examples to features:  97%|█████████▋| 11489/11873 [01:23<00:02, 131.52it/s]
#
# convert squad examples to features:  97%|█████████▋| 11521/11873 [01:24<00:02, 123.95it/s]
#
# convert squad examples to features:  97%|█████████▋| 11553/11873 [01:24<00:02, 129.31it/s]
#
# convert squad examples to features:  98%|█████████▊| 11585/11873 [01:24<00:02, 123.37it/s]
#
# convert squad examples to features:  98%|█████████▊| 11617/11873 [01:25<00:02, 124.31it/s]
#
# convert squad examples to features:  98%|█████████▊| 11649/11873 [01:25<00:01, 118.68it/s]
#
# convert squad examples to features:  98%|█████████▊| 11681/11873 [01:25<00:01, 117.19it/s]
#
# convert squad examples to features:  99%|█████████▊| 11713/11873 [01:25<00:01, 123.76it/s]
#
# convert squad examples to features:  99%|█████████▉| 11745/11873 [01:26<00:00, 130.96it/s]
#
# convert squad examples to features:  99%|█████████▉| 11777/11873 [01:26<00:00, 135.38it/s]
#
# convert squad examples to features:  99%|█████████▉| 11809/11873 [01:26<00:00, 145.40it/s]
#
# convert squad examples to features: 100%|██████████| 11873/11873 [01:26<00:00, 137.05it/s]
#
#
# add example index and unique id: 100%|██████████| 11873/11873 [00:00<00:00, 783372.21it/s]

# %%
dev_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=False)

# %%
import json
from datetime import datetime
from transformers.data.processors.squad import SquadFeatures
bs1 = bs1.to(device)
bs1.eval()

start_time = datetime.now()
outputs = dict()

for i, batch in enumerate(dev_loader):
    c_q_pairs = batch[0].to(device)
    attention_mask = batch[1].to(device)
    token_type_ids = batch[2].to(device)
    indices = bs1.predict(c_q_pairs, attention_mask, token_type_ids)
    start, end = indices[0][0], indices[0][1]
    tokens = tokenizer.convert_ids_to_tokens(c_q_pairs.view(-1).tolist())#[start:end+1])

    token_to_orig_map = features[i].token_to_orig_map
    if start in token_to_orig_map and end in token_to_orig_map:
        start, end = token_to_orig_map[start], token_to_orig_map[end]
        tokens = examples[features[i].example_index].doc_tokens[start:end+1] if start <= end else ""
        answer = ' '.join(tokens)
    else:
        answer = ""    
    

    if '[CLS]' in answer:
        answer = ""

    q_id = examples[features[i].example_index].qas_id
    if q_id not in outputs:
        outputs[examples[features[i].example_index].qas_id] = answer


    if i % 100 == 0:
        print('done with example : {}'.format(i))

print('total time for dev predictions : {}'.format(datetime.now() - start_time))
with open('bert-dev-preds.json', 'w') as f:
    json.dump(outputs, f)
# Out:
# done with example : 0
# done with example : 100
# done with example : 200
# done with example : 300
# done with example : 400
# done with example : 500
# done with example : 600
# done with example : 700
# done with example : 800
# done with example : 900
# done with example : 1000
# done with example : 1100
# done with example : 1200
# done with example : 1300
# done with example : 1400
# done with example : 1500
# done with example : 1600
# done with example : 1700
# done with example : 1800
# done with example : 1900
# done with example : 2000
# done with example : 2100
# done with example : 2200
# done with example : 2300
# done with example : 2400
# done with example : 2500
# done with example : 2600
# done with example : 2700
# done with example : 2800
# done with example : 2900
# done with example : 3000
# done with example : 3100
# done with example : 3200
# done with example : 3300
# done with example : 3400
# done with example : 3500
# done with example : 3600
# done with example : 3700
# done with example : 3800
# done with example : 3900
# done with example : 4000
# done with example : 4100
# done with example : 4200
# done with example : 4300
# done with example : 4400
# done with example : 4500
# done with example : 4600
# done with example : 4700
# done with example : 4800
# done with example : 4900
# done with example : 5000
# done with example : 5100
# done with example : 5200
# done with example : 5300
# done with example : 5400
# done with example : 5500
# done with example : 5600
# done with example : 5700
# done with example : 5800
# done with example : 5900
# done with example : 6000
# done with example : 6100
# done with example : 6200
# done with example : 6300
# done with example : 6400
# done with example : 6500
# done with example : 6600
# done with example : 6700
# done with example : 6800
# done with example : 6900
# done with example : 7000
# done with example : 7100
# done with example : 7200
# done with example : 7300
# done with example : 7400
# done with example : 7500
# done with example : 7600
# done with example : 7700
# done with example : 7800
# done with example : 7900
# done with example : 8000
# done with example : 8100
# done with example : 8200
# done with example : 8300
# done with example : 8400
# done with example : 8500
# done with example : 8600
# done with example : 8700
# done with example : 8800
# done with example : 8900
# done with example : 9000
# done with example : 9100
# done with example : 9200
# done with example : 9300
# done with example : 9400
# done with example : 9500
# done with example : 9600
# done with example : 9700
# done with example : 9800
# done with example : 9900
# done with example : 10000
# done with example : 10100
# done with example : 10200
# done with example : 10300
# done with example : 10400
# done with example : 10500
# done with example : 10600
# done with example : 10700
# done with example : 10800
# done with example : 10900
# done with example : 11000
# done with example : 11100
# done with example : 11200
# done with example : 11300
# done with example : 11400
# done with example : 11500
# done with example : 11600
# done with example : 11700
# done with example : 11800
# done with example : 11900
# done with example : 12000
# total time for dev predictions : 0:04:21.495923

# %% [markdown]
# # distilBERT Model

# %%
import torch

from torch import nn
from transformers import DistilBertModel, DistilBertConfig, DistilBertTokenizer

class DISTILBERT_SQUAD(nn.Module):
    def __init__(self):
        super(DISTILBERT_SQUAD, self).__init__()

        self.distilbert_model = DistilBertModel.from_pretrained('distilbert-base-uncased')

        self.fc_layers = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        )

        self.criterion = nn.CrossEntropyLoss()



    def forward(self, c_q_pairs, attention_mask, token_type_ids, start_indices, end_indices):

        bert_encoded = self.distilbert_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        start_indices = (start_indices).clamp(0, start_outputs.shape[1]-1)
        end_indices = (end_indices).clamp(0, start_outputs.shape[1]-1)

        start_loss = self.criterion(start_outputs, start_indices)
        end_loss = self.criterion(end_outputs, end_indices)

        return 2*start_loss + end_loss


    def predict(self, c_q_pairs, attention_mask, token_type_ids):
        bert_encoded = self.distilbert_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        starts, s_ind = start_outputs.max(1)
        ends, e_ind = end_outputs.max(1)


        answers = []
        for i in range(start_outputs.shape[0]):
            start = s_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            end = e_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            answers.append([start, end])
        return answers

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# %%
bs1 = DISTILBERT_SQUAD()
bs1.load_state_dict(torch.load('/content/drive/My Drive/cis530project/distilbert-squad.pt'))
# Out:
# <All keys matched successfully>

# %%
features, dataset = squad_convert_examples_to_features(
    examples=examples,
    tokenizer=tokenizer,
    max_seq_length=512,
    doc_stride=128,
    max_query_length=128,
    is_training=False,
    return_dataset='pt',
    threads=1
)
# Out:
# convert squad examples to features:   0%|          | 0/11873 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/11873 [00:00<52:44,  3.75it/s]
#
# convert squad examples to features:   0%|          | 33/11873 [00:00<37:11,  5.31it/s]
#
# convert squad examples to features:   1%|          | 65/11873 [00:00<26:24,  7.45it/s]
#
# convert squad examples to features:   1%|          | 97/11873 [00:00<18:50, 10.42it/s]
#
# convert squad examples to features:   1%|          | 129/11873 [00:01<13:28, 14.52it/s]
#
# convert squad examples to features:   1%|▏         | 161/11873 [00:01<09:40, 20.18it/s]
#
# convert squad examples to features:   2%|▏         | 193/11873 [00:01<07:04, 27.53it/s]
#
# convert squad examples to features:   2%|▏         | 225/11873 [00:01<05:18, 36.52it/s]
#
# convert squad examples to features:   2%|▏         | 257/11873 [00:01<03:59, 48.53it/s]
#
# convert squad examples to features:   2%|▏         | 289/11873 [00:02<03:10, 60.92it/s]
#
# convert squad examples to features:   3%|▎         | 321/11873 [00:02<02:33, 75.37it/s]
#
# convert squad examples to features:   3%|▎         | 353/11873 [00:02<02:05, 92.00it/s]
#
# convert squad examples to features:   3%|▎         | 385/11873 [00:02<01:45, 109.36it/s]
#
# convert squad examples to features:   4%|▎         | 417/11873 [00:02<01:30, 126.32it/s]
#
# convert squad examples to features:   4%|▍         | 449/11873 [00:02<01:23, 136.89it/s]
#
# convert squad examples to features:   4%|▍         | 481/11873 [00:03<01:17, 146.14it/s]
#
# convert squad examples to features:   4%|▍         | 513/11873 [00:03<01:16, 149.26it/s]
#
# convert squad examples to features:   5%|▍         | 545/11873 [00:03<01:13, 154.02it/s]
#
# convert squad examples to features:   5%|▍         | 577/11873 [00:03<01:05, 173.12it/s]
#
# convert squad examples to features:   5%|▌         | 609/11873 [00:03<00:59, 188.32it/s]
#
# convert squad examples to features:   5%|▌         | 641/11873 [00:03<00:58, 192.84it/s]
#
# convert squad examples to features:   6%|▌         | 673/11873 [00:04<00:59, 188.30it/s]
#
# convert squad examples to features:   6%|▌         | 705/11873 [00:04<01:01, 180.26it/s]
#
# convert squad examples to features:   6%|▌         | 737/11873 [00:04<01:09, 161.19it/s]
#
# convert squad examples to features:   6%|▋         | 769/11873 [00:04<01:01, 179.89it/s]
#
# convert squad examples to features:   7%|▋         | 801/11873 [00:04<00:59, 186.69it/s]
#
# convert squad examples to features:   7%|▋         | 833/11873 [00:04<00:53, 204.97it/s]
#
# convert squad examples to features:   7%|▋         | 865/11873 [00:05<00:49, 223.42it/s]
#
# convert squad examples to features:   8%|▊         | 897/11873 [00:05<00:48, 224.97it/s]
#
# convert squad examples to features:   8%|▊         | 929/11873 [00:05<00:44, 244.22it/s]
#
# convert squad examples to features:   8%|▊         | 961/11873 [00:05<00:53, 203.45it/s]
#
# convert squad examples to features:   8%|▊         | 993/11873 [00:05<00:56, 191.77it/s]
#
# convert squad examples to features:   9%|▊         | 1025/11873 [00:05<00:59, 180.86it/s]
#
# convert squad examples to features:   9%|▉         | 1057/11873 [00:06<01:01, 174.84it/s]
#
# convert squad examples to features:   9%|▉         | 1089/11873 [00:06<01:07, 159.45it/s]
#
# convert squad examples to features:   9%|▉         | 1121/11873 [00:06<01:06, 162.44it/s]
#
# convert squad examples to features:  10%|▉         | 1153/11873 [00:06<01:06, 162.40it/s]
#
# convert squad examples to features:  10%|▉         | 1185/11873 [00:06<01:03, 167.79it/s]
#
# convert squad examples to features:  10%|█         | 1217/11873 [00:07<01:05, 162.07it/s]
#
# convert squad examples to features:  11%|█         | 1249/11873 [00:07<01:05, 161.81it/s]
#
# convert squad examples to features:  11%|█         | 1281/11873 [00:07<01:04, 165.42it/s]
#
# convert squad examples to features:  11%|█         | 1313/11873 [00:07<01:04, 162.57it/s]
#
# convert squad examples to features:  11%|█▏        | 1345/11873 [00:07<01:02, 168.27it/s]
#
# convert squad examples to features:  12%|█▏        | 1377/11873 [00:08<00:59, 177.70it/s]
#
# convert squad examples to features:  12%|█▏        | 1409/11873 [00:08<01:03, 164.21it/s]
#
# convert squad examples to features:  12%|█▏        | 1441/11873 [00:08<01:09, 149.31it/s]
#
# convert squad examples to features:  12%|█▏        | 1473/11873 [00:08<01:06, 156.14it/s]
#
# convert squad examples to features:  13%|█▎        | 1505/11873 [00:08<01:05, 158.49it/s]
#
# convert squad examples to features:  13%|█▎        | 1537/11873 [00:09<01:06, 154.45it/s]
#
# convert squad examples to features:  13%|█▎        | 1569/11873 [00:09<01:05, 156.55it/s]
#
# convert squad examples to features:  13%|█▎        | 1601/11873 [00:09<01:09, 146.83it/s]
#
# convert squad examples to features:  14%|█▍        | 1633/11873 [00:09<01:07, 151.37it/s]
#
# convert squad examples to features:  14%|█▍        | 1665/11873 [00:10<01:15, 134.58it/s]
#
# convert squad examples to features:  14%|█▍        | 1697/11873 [00:10<01:09, 146.53it/s]
#
# convert squad examples to features:  15%|█▍        | 1729/11873 [00:10<01:10, 143.08it/s]
#
# convert squad examples to features:  15%|█▍        | 1761/11873 [00:10<01:13, 137.18it/s]
#
# convert squad examples to features:  15%|█▌        | 1793/11873 [00:10<01:15, 133.84it/s]
#
# convert squad examples to features:  15%|█▌        | 1825/11873 [00:11<01:10, 141.76it/s]
#
# convert squad examples to features:  16%|█▌        | 1857/11873 [00:11<01:13, 135.82it/s]
#
# convert squad examples to features:  16%|█▌        | 1889/11873 [00:11<01:09, 143.70it/s]
#
# convert squad examples to features:  16%|█▌        | 1921/11873 [00:11<01:06, 149.00it/s]
#
# convert squad examples to features:  16%|█▋        | 1953/11873 [00:12<01:07, 146.35it/s]
#
# convert squad examples to features:  17%|█▋        | 1985/11873 [00:12<01:03, 155.16it/s]
#
# convert squad examples to features:  17%|█▋        | 2017/11873 [00:12<01:04, 151.96it/s]
#
#
# convert squad examples to features:  89%|████████▉ | 10561/11873 [01:18<00:10, 119.44it/s]
#
# convert squad examples to features:  89%|████████▉ | 10593/11873 [01:18<00:09, 129.00it/s]
#
# convert squad examples to features:  89%|████████▉ | 10625/11873 [01:18<00:10, 119.04it/s]
#
# convert squad examples to features:  90%|████████▉ | 10657/11873 [01:18<00:09, 129.34it/s]
#
# convert squad examples to features:  90%|█████████ | 10689/11873 [01:19<00:08, 133.99it/s]
#
# convert squad examples to features:  90%|█████████ | 10721/11873 [01:19<00:08, 136.41it/s]
#
# convert squad examples to features:  91%|█████████ | 10753/11873 [01:19<00:08, 138.14it/s]
#
# convert squad examples to features:  91%|█████████ | 10785/11873 [01:19<00:07, 137.88it/s]
#
# convert squad examples to features:  91%|█████████ | 10817/11873 [01:20<00:08, 122.20it/s]
#
# convert squad examples to features:  91%|█████████▏| 10849/11873 [01:20<00:08, 127.75it/s]
#
# convert squad examples to features:  92%|█████████▏| 10881/11873 [01:20<00:07, 131.12it/s]
#
# convert squad examples to features:  92%|█████████▏| 10913/11873 [01:20<00:07, 129.79it/s]
#
# convert squad examples to features:  92%|█████████▏| 10945/11873 [01:21<00:06, 137.07it/s]
#
# convert squad examples to features:  92%|█████████▏| 10977/11873 [01:21<00:06, 147.10it/s]
#
# convert squad examples to features:  93%|█████████▎| 11009/11873 [01:21<00:05, 156.05it/s]
#
# convert squad examples to features:  93%|█████████▎| 11041/11873 [01:21<00:05, 162.53it/s]
#
# convert squad examples to features:  93%|█████████▎| 11073/11873 [01:21<00:04, 163.32it/s]
#
# convert squad examples to features:  94%|█████████▎| 11105/11873 [01:21<00:04, 156.05it/s]
#
# convert squad examples to features:  94%|█████████▍| 11137/11873 [01:22<00:04, 155.88it/s]
#
# convert squad examples to features:  94%|█████████▍| 11169/11873 [01:22<00:04, 152.51it/s]
#
# convert squad examples to features:  94%|█████████▍| 11201/11873 [01:22<00:04, 147.74it/s]
#
# convert squad examples to features:  95%|█████████▍| 11233/11873 [01:22<00:04, 137.80it/s]
#
# convert squad examples to features:  95%|█████████▍| 11265/11873 [01:23<00:04, 144.25it/s]
#
# convert squad examples to features:  95%|█████████▌| 11297/11873 [01:23<00:04, 143.03it/s]
#
# convert squad examples to features:  95%|█████████▌| 11329/11873 [01:23<00:03, 141.18it/s]
#
# convert squad examples to features:  96%|█████████▌| 11361/11873 [01:23<00:03, 142.58it/s]
#
# convert squad examples to features:  96%|█████████▌| 11393/11873 [01:24<00:03, 138.38it/s]
#
# convert squad examples to features:  96%|█████████▌| 11425/11873 [01:24<00:03, 146.78it/s]
#
# convert squad examples to features:  96%|█████████▋| 11457/11873 [01:24<00:03, 136.10it/s]
#
# convert squad examples to features:  97%|█████████▋| 11489/11873 [01:24<00:02, 132.16it/s]
#
# convert squad examples to features:  97%|█████████▋| 11521/11873 [01:25<00:02, 123.36it/s]
#
# convert squad examples to features:  97%|█████████▋| 11553/11873 [01:25<00:02, 128.05it/s]
#
# convert squad examples to features:  98%|█████████▊| 11585/11873 [01:25<00:02, 122.47it/s]
#
# convert squad examples to features:  98%|█████████▊| 11617/11873 [01:25<00:02, 124.59it/s]
#
# convert squad examples to features:  98%|█████████▊| 11649/11873 [01:26<00:01, 119.41it/s]
#
# convert squad examples to features:  98%|█████████▊| 11681/11873 [01:26<00:01, 116.59it/s]
#
# convert squad examples to features:  99%|█████████▊| 11713/11873 [01:26<00:01, 123.05it/s]
#
# convert squad examples to features:  99%|█████████▉| 11745/11873 [01:26<00:00, 133.24it/s]
#
# convert squad examples to features:  99%|█████████▉| 11777/11873 [01:27<00:00, 136.36it/s]
#
# convert squad examples to features:  99%|█████████▉| 11809/11873 [01:27<00:00, 144.83it/s]
#
# convert squad examples to features: 100%|██████████| 11873/11873 [01:27<00:00, 135.82it/s]
#
#
# add example index and unique id: 100%|██████████| 11873/11873 [00:00<00:00, 824950.66it/s]

# %%
import json
from datetime import datetime
from transformers.data.processors.squad import SquadFeatures
bs1 = bs1.to(device)
bs1.eval()

start_time = datetime.now()
outputs = dict()

for i, batch in enumerate(dev_loader):
    c_q_pairs = batch[0].to(device)
    attention_mask = batch[1].to(device)
    token_type_ids = batch[2].to(device)
    indices = bs1.predict(c_q_pairs, attention_mask, token_type_ids)
    start, end = indices[0][0], indices[0][1]
    tokens = tokenizer.convert_ids_to_tokens(c_q_pairs.view(-1).tolist())#[start:end+1])

    token_to_orig_map = features[i].token_to_orig_map
    if start in token_to_orig_map and end in token_to_orig_map:
        start, end = token_to_orig_map[start], token_to_orig_map[end]
        tokens = examples[features[i].example_index].doc_tokens[start:end+1] if start <= end else ""
        answer = ' '.join(tokens)
    else:
        answer = ""    
    

    if '[CLS]' in answer:
        answer = ""

    q_id = examples[features[i].example_index].qas_id
    if q_id not in outputs:
        outputs[examples[features[i].example_index].qas_id] = answer


    if i % 100 == 0:
        print('done with example : {}'.format(i))

print('total time for dev predictions : {}'.format(datetime.now() - start_time))
with open('distilbert-dev-preds.json', 'w') as f:
    json.dump(outputs, f)
# Out:
# done with example : 0
# done with example : 100
# done with example : 200
# done with example : 300
# done with example : 400
# done with example : 500
# done with example : 600
# done with example : 700
# done with example : 800
# done with example : 900
# done with example : 1000
# done with example : 1100
# done with example : 1200
# done with example : 1300
# done with example : 1400
# done with example : 1500
# done with example : 1600
# done with example : 1700
# done with example : 1800
# done with example : 1900
# done with example : 2000
# done with example : 2100
# done with example : 2200
# done with example : 2300
# done with example : 2400
# done with example : 2500
# done with example : 2600
# done with example : 2700
# done with example : 2800
# done with example : 2900
# done with example : 3000
# done with example : 3100
# done with example : 3200
# done with example : 3300
# done with example : 3400
# done with example : 3500
# done with example : 3600
# done with example : 3700
# done with example : 3800
# done with example : 3900
# done with example : 4000
# done with example : 4100
# done with example : 4200
# done with example : 4300
# done with example : 4400
# done with example : 4500
# done with example : 4600
# done with example : 4700
# done with example : 4800
# done with example : 4900
# done with example : 5000
# done with example : 5100
# done with example : 5200
# done with example : 5300
# done with example : 5400
# done with example : 5500
# done with example : 5600
# done with example : 5700
# done with example : 5800
# done with example : 5900
# done with example : 6000
# done with example : 6100
# done with example : 6200
# done with example : 6300
# done with example : 6400
# done with example : 6500
# done with example : 6600
# done with example : 6700
# done with example : 6800
# done with example : 6900
# done with example : 7000
# done with example : 7100
# done with example : 7200
# done with example : 7300
# done with example : 7400
# done with example : 7500
# done with example : 7600
# done with example : 7700
# done with example : 7800
# done with example : 7900
# done with example : 8000
# done with example : 8100
# done with example : 8200
# done with example : 8300
# done with example : 8400
# done with example : 8500
# done with example : 8600
# done with example : 8700
# done with example : 8800
# done with example : 8900
# done with example : 9000
# done with example : 9100
# done with example : 9200
# done with example : 9300
# done with example : 9400
# done with example : 9500
# done with example : 9600
# done with example : 9700
# done with example : 9800
# done with example : 9900
# done with example : 10000
# done with example : 10100
# done with example : 10200
# done with example : 10300
# done with example : 10400
# done with example : 10500
# done with example : 10600
# done with example : 10700
# done with example : 10800
# done with example : 10900
# done with example : 11000
# done with example : 11100
# done with example : 11200
# done with example : 11300
# done with example : 11400
# done with example : 11500
# done with example : 11600
# done with example : 11700
# done with example : 11800
# done with example : 11900
# done with example : 12000
# total time for dev predictions : 0:02:11.660367

# %% [markdown]
# # RoBERTa Model

# %%
import torch

from torch import nn
from transformers import RobertaModel, RobertaConfig, RobertaTokenizer

class ROBERTA_SQUAD(nn.Module):
    def __init__(self):
        super(ROBERTA_SQUAD, self).__init__()

        self.roberta_model = RobertaModel.from_pretrained('roberta-base')

        self.fc_layers = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        )

        self.criterion = nn.CrossEntropyLoss()



    def forward(self, c_q_pairs, attention_mask, token_type_ids, start_indices, end_indices):

        bert_encoded = self.roberta_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        start_indices = (start_indices).clamp(0, start_outputs.shape[1]-1)
        end_indices = (end_indices).clamp(0, start_outputs.shape[1]-1)

        start_loss = self.criterion(start_outputs, start_indices)
        end_loss = self.criterion(end_outputs, end_indices)

        return 2*start_loss + end_loss


    def predict(self, c_q_pairs, attention_mask, token_type_ids):
        bert_encoded = self.roberta_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        starts, s_ind = start_outputs.max(1)
        ends, e_ind = end_outputs.max(1)


        answers = []
        for i in range(start_outputs.shape[0]):
            start = s_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            end = e_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            answers.append([start, end])
        return answers

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# %%
bs1 = ROBERTA_SQUAD()
bs1.load_state_dict(torch.load('/content/drive/My Drive/cis530project/roberta-squad.pt'))
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
#
#   6%|▌         | 2/35 [00:00<00:02, 13.48it/s]
#
#  11%|█▏        | 4/35 [00:00<00:02, 14.18it/s]
#
#  17%|█▋        | 6/35 [00:00<00:02, 12.68it/s]
#
#  20%|██        | 7/35 [00:00<00:02, 10.74it/s]
#
#  23%|██▎       | 8/35 [00:00<00:02,  9.68it/s]
#
#  29%|██▊       | 10/35 [00:01<00:03,  8.17it/s]
#
#  34%|███▍      | 12/35 [00:01<00:02,  8.70it/s]
#
#  40%|████      | 14/35 [00:01<00:02,  8.78it/s]
#
#  46%|████▌     | 16/35 [00:01<00:02,  9.37it/s]
#
#  51%|█████▏    | 18/35 [00:01<00:01,  9.83it/s]
#
#  57%|█████▋    | 20/35 [00:01<00:01, 10.89it/s]
#
#  63%|██████▎   | 22/35 [00:02<00:01, 11.40it/s]
#
#  69%|██████▊   | 24/35 [00:02<00:01,  9.61it/s]
#
#  74%|███████▍  | 26/35 [00:02<00:01,  8.22it/s]
#
#  80%|████████  | 28/35 [00:02<00:00,  9.25it/s]
#
#  86%|████████▌ | 30/35 [00:03<00:00,  8.96it/s]
#
#  89%|████████▊ | 31/35 [00:03<00:00,  8.85it/s]
#
#  91%|█████████▏| 32/35 [00:03<00:00,  8.43it/s]
#
#  94%|█████████▍| 33/35 [00:03<00:00,  7.87it/s]
#
#  97%|█████████▋| 34/35 [00:03<00:00,  7.94it/s]
#
# 100%|██████████| 35/35 [00:03<00:00,  9.28it/s]

# %%
features, dataset = squad_convert_examples_to_features(
    examples=examples,
    tokenizer=tokenizer,
    max_seq_length=512,
    doc_stride=128,
    max_query_length=128,
    is_training=False,
    return_dataset='pt',
    threads=1
)
# Out:
# convert squad examples to features:   0%|          | 0/11873 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/11873 [00:00<35:32,  5.57it/s]
#
# convert squad examples to features:   0%|          | 33/11873 [00:00<25:06,  7.86it/s]
#
# convert squad examples to features:   1%|          | 65/11873 [00:00<17:45, 11.09it/s]
#
# convert squad examples to features:   1%|          | 97/11873 [00:00<12:39, 15.50it/s]
#
# convert squad examples to features:   1%|          | 129/11873 [00:00<09:02, 21.63it/s]
#
# convert squad examples to features:   2%|▏         | 193/11873 [00:00<06:29, 30.02it/s]
#
# convert squad examples to features:   2%|▏         | 225/11873 [00:01<04:45, 40.74it/s]
#
# convert squad examples to features:   2%|▏         | 289/11873 [00:01<03:30, 54.90it/s]
#
# convert squad examples to features:   3%|▎         | 321/11873 [00:01<02:39, 72.28it/s]
#
# convert squad examples to features:   3%|▎         | 353/11873 [00:01<02:02, 93.74it/s]
#
# convert squad examples to features:   3%|▎         | 385/11873 [00:01<01:36, 118.60it/s]
#
# convert squad examples to features:   4%|▍         | 449/11873 [00:01<01:18, 146.35it/s]
#
# convert squad examples to features:   4%|▍         | 481/11873 [00:01<01:07, 169.52it/s]
#
# convert squad examples to features:   4%|▍         | 513/11873 [00:02<01:00, 188.42it/s]
#
# convert squad examples to features:   5%|▍         | 545/11873 [00:02<00:54, 206.98it/s]
#
# convert squad examples to features:   5%|▌         | 609/11873 [00:02<00:46, 239.91it/s]
#
# convert squad examples to features:   6%|▌         | 673/11873 [00:02<00:43, 256.13it/s]
# convert squad examples to features:  16%|█▌        | 1889/11873 [00:07<00:44, 224.89it/s]
#
# convert squad examples to features:  16%|█▌        | 1921/11873 [00:07<00:42, 232.51it/s]
#
# convert squad examples to features:  16%|█▋        | 1953/11873 [00:07<00:42, 232.22it/s]
#
# convert squad examples to features:  17%|█▋        | 1985/11873 [00:07<00:40, 241.72it/s]
#
# convert squad examples to features:  17%|█▋        | 2017/11873 [00:07<00:40, 240.80it/s]
#
# convert squad examples to features:  17%|█▋        | 2049/11873 [00:07<00:40, 244.48it/s]
#
# convert squad examples to features:  18%|█▊        | 2081/11873 [00:08<00:39, 248.59it/s]
#
# convert squad examples to features:  18%|█▊        | 2113/11873 [00:08<00:40, 241.33it/s]
#
# convert squad examples to features:  18%|█▊        | 2145/11873 [00:08<00:43, 224.11it/s]
#
# convert squad examples to features:  18%|█▊        | 2177/11873 [00:08<00:42, 229.52it/s]
#
# convert squad examples to features:  19%|█▊        | 2209/11873 [00:08<00:40, 236.88it/s]
#
# convert squad examples to features:  19%|█▉        | 2241/11873 [00:08<00:41, 231.53it/s]
#
# convert squad examples to features:  19%|█▉        | 2273/11873 [00:08<00:43, 219.15it/s]
#
# convert squad examples to features:  19%|█▉        | 2305/11873 [00:09<00:41, 228.14it/s]
#
# convert squad examples to features:  20%|█▉        | 2337/11873 [00:09<00:38, 245.63it/s]
#
# convert squad examples to features:  20%|█▉        | 2369/11873 [00:09<00:38, 248.62it/s]
#
# convert squad examples to features:  20%|██        | 2401/11873 [00:09<00:39, 238.09it/s]
#
# convert squad examples to features:  20%|██        | 2433/11873 [00:09<00:39, 236.62it/s]
#
# convert squad examples to features:  21%|██        | 2465/11873 [00:09<00:40, 229.93it/s]
#
# convert squad examples to features:  21%|██        | 2497/11873 [00:09<00:39, 239.34it/s]
#
# convert squad examples to features:  21%|██▏       | 2529/11873 [00:09<00:37, 250.91it/s]
#
# convert squad examples to features:  22%|██▏       | 2561/11873 [00:10<00:39, 236.34it/s]
#
# convert squad examples to features:  22%|██▏       | 2593/11873 [00:10<00:36, 255.35it/s]
#
# convert squad examples to features:  22%|██▏       | 2625/11873 [00:10<00:36, 253.17it/s]
#
# convert squad examples to features:  22%|██▏       | 2657/11873 [00:10<00:35, 263.24it/s]
#
# convert squad examples to features:  23%|██▎       | 2689/11873 [00:10<00:34, 263.01it/s]
#
# convert squad examples to features:  23%|██▎       | 2721/11873 [00:10<00:36, 248.38it/s]
#
# convert squad examples to features:  23%|██▎       | 2753/11873 [00:10<00:38, 237.41it/s]
#
# convert squad examples to features:  23%|██▎       | 2785/11873 [00:10<00:35, 256.05it/s]
#
# convert squad examples to features:  24%|██▍       | 2849/11873 [00:11<00:34, 260.36it/s]
#
# convert squad examples to features:  24%|██▍       | 2881/11873 [00:11<00:37, 240.94it/s]
#
# convert squad examples to features:  25%|██▍       | 2913/11873 [00:11<00:36, 242.60it/s]
#
# convert squad examples to features:  25%|██▍       | 2945/11873 [00:11<00:35, 252.65it/s]
#
# convert squad examples to features:  25%|██▌       | 2977/11873 [00:11<00:45, 196.11it/s]
# convert squad examples to features:  80%|████████  | 9505/11873 [00:43<00:09, 245.82it/s]
#
# convert squad examples to features:  80%|████████  | 9537/11873 [00:43<00:09, 256.15it/s]
#
# convert squad examples to features:  81%|████████  | 9569/11873 [00:43<00:09, 244.65it/s]
#
# convert squad examples to features:  81%|████████  | 9601/11873 [00:43<00:09, 237.83it/s]
#
# convert squad examples to features:  81%|████████  | 9633/11873 [00:44<00:09, 227.74it/s]
#
# convert squad examples to features:  81%|████████▏ | 9665/11873 [00:44<00:08, 249.21it/s]
#
# convert squad examples to features:  82%|████████▏ | 9697/11873 [00:44<00:08, 246.36it/s]
#
# convert squad examples to features:  82%|████████▏ | 9729/11873 [00:44<00:08, 256.88it/s]
#
# convert squad examples to features:  82%|████████▏ | 9761/11873 [00:44<00:08, 237.23it/s]
#
# convert squad examples to features:  82%|████████▏ | 9793/11873 [00:44<00:09, 231.02it/s]
#
# convert squad examples to features:  83%|████████▎ | 9825/11873 [00:44<00:08, 246.61it/s]
#
# convert squad examples to features:  83%|████████▎ | 9857/11873 [00:44<00:08, 236.12it/s]
#
# convert squad examples to features:  83%|████████▎ | 9889/11873 [00:45<00:08, 239.92it/s]
#
# convert squad examples to features:  84%|████████▎ | 9921/11873 [00:45<00:08, 233.58it/s]
#
# convert squad examples to features:  84%|████████▍ | 9953/11873 [00:45<00:07, 243.45it/s]
#
# convert squad examples to features:  84%|████████▍ | 10017/11873 [00:45<00:07, 262.34it/s]
#
# convert squad examples to features:  85%|████████▍ | 10049/11873 [00:45<00:06, 265.04it/s]
#
# convert squad examples to features:  85%|████████▍ | 10081/11873 [00:45<00:06, 267.04it/s]
#
# convert squad examples to features:  85%|████████▌ | 10113/11873 [00:45<00:06, 264.94it/s]
#
# convert squad examples to features:  85%|████████▌ | 10145/11873 [00:46<00:06, 255.74it/s]
#
# convert squad examples to features:  86%|████████▌ | 10177/11873 [00:46<00:07, 233.27it/s]
#
# convert squad examples to features:  86%|████████▌ | 10209/11873 [00:46<00:06, 244.81it/s]
#
# convert squad examples to features:  86%|████████▋ | 10241/11873 [00:46<00:06, 250.10it/s]
#
# convert squad examples to features:  87%|████████▋ | 10273/11873 [00:46<00:08, 198.15it/s]
#
# convert squad examples to features:  87%|████████▋ | 10305/11873 [00:46<00:07, 212.31it/s]
#
# convert squad examples to features:  87%|████████▋ | 10337/11873 [00:46<00:07, 216.93it/s]
#
# convert squad examples to features:  87%|████████▋ | 10369/11873 [00:47<00:06, 220.95it/s]
#
# convert squad examples to features:  88%|████████▊ | 10401/11873 [00:47<00:07, 209.33it/s]
#
# convert squad examples to features:  88%|████████▊ | 10433/11873 [00:47<00:06, 227.20it/s]
#
# convert squad examples to features:  88%|████████▊ | 10465/11873 [00:47<00:05, 241.70it/s]
#
# convert squad examples to features:  88%|████████▊ | 10497/11873 [00:47<00:05, 235.01it/s]
#
# convert squad examples to features:  89%|████████▊ | 10529/11873 [00:47<00:06, 209.69it/s]
#
# convert squad examples to features:  89%|████████▉ | 10561/11873 [00:47<00:06, 199.59it/s]
#
# convert squad examples to features:  89%|████████▉ | 10593/11873 [00:48<00:06, 209.86it/s]
#
# convert squad examples to features:  89%|████████▉ | 10625/11873 [00:48<00:06, 195.27it/s]
#
# convert squad examples to features:  90%|████████▉ | 10657/11873 [00:48<00:05, 212.48it/s]
#
# convert squad examples to features:  90%|█████████ | 10689/11873 [00:48<00:05, 218.84it/s]
#
# convert squad examples to features:  90%|█████████ | 10721/11873 [00:48<00:05, 223.88it/s]
#
# convert squad examples to features:  91%|█████████ | 10753/11873 [00:48<00:05, 220.31it/s]
#
# convert squad examples to features:  91%|█████████ | 10785/11873 [00:48<00:04, 230.69it/s]
#
# convert squad examples to features:  91%|█████████ | 10817/11873 [00:49<00:05, 206.16it/s]
#
# convert squad examples to features:  91%|█████████▏| 10849/11873 [00:49<00:04, 214.11it/s]
#
# convert squad examples to features:  92%|█████████▏| 10881/11873 [00:49<00:04, 219.22it/s]
#
# convert squad examples to features:  92%|█████████▏| 10913/11873 [00:49<00:04, 215.72it/s]
#
# convert squad examples to features:  92%|█████████▏| 10945/11873 [00:49<00:04, 230.18it/s]
#
# convert squad examples to features:  92%|█████████▏| 10977/11873 [00:49<00:03, 246.12it/s]
#
# convert squad examples to features:  93%|█████████▎| 11009/11873 [00:49<00:03, 261.42it/s]
#
# convert squad examples to features:  93%|█████████▎| 11041/11873 [00:50<00:03, 263.24it/s]
#
# convert squad examples to features:  93%|█████████▎| 11073/11873 [00:50<00:03, 265.43it/s]
#
# convert squad examples to features:  94%|█████████▎| 11105/11873 [00:50<00:03, 252.89it/s]
#
# convert squad examples to features:  94%|█████████▍| 11137/11873 [00:50<00:02, 257.90it/s]
#
# convert squad examples to features:  94%|█████████▍| 11169/11873 [00:50<00:02, 248.93it/s]
#
# convert squad examples to features:  94%|█████████▍| 11201/11873 [00:50<00:02, 247.04it/s]
#
# convert squad examples to features:  95%|█████████▍| 11233/11873 [00:50<00:02, 232.83it/s]
#
# convert squad examples to features:  95%|█████████▍| 11265/11873 [00:50<00:02, 243.36it/s]
#
# convert squad examples to features:  95%|█████████▌| 11297/11873 [00:51<00:02, 246.25it/s]
#
# convert squad examples to features:  95%|█████████▌| 11329/11873 [00:51<00:02, 240.22it/s]
#
# convert squad examples to features:  96%|█████████▌| 11361/11873 [00:51<00:02, 243.12it/s]
#
# convert squad examples to features:  96%|█████████▌| 11393/11873 [00:51<00:02, 232.79it/s]
#
# convert squad examples to features:  96%|█████████▌| 11425/11873 [00:51<00:01, 248.98it/s]
#
# convert squad examples to features:  96%|█████████▋| 11457/11873 [00:51<00:01, 230.91it/s]
#
# convert squad examples to features:  97%|█████████▋| 11489/11873 [00:51<00:01, 222.64it/s]
#
# convert squad examples to features:  97%|█████████▋| 11521/11873 [00:52<00:01, 205.36it/s]
#
# convert squad examples to features:  97%|█████████▋| 11553/11873 [00:52<00:01, 218.04it/s]
#
# convert squad examples to features:  98%|█████████▊| 11585/11873 [00:52<00:01, 202.29it/s]
#
# convert squad examples to features:  98%|█████████▊| 11617/11873 [00:52<00:01, 214.78it/s]
#
# convert squad examples to features:  98%|█████████▊| 11649/11873 [00:52<00:01, 201.77it/s]
#
# convert squad examples to features:  98%|█████████▊| 11681/11873 [00:52<00:00, 201.31it/s]
#
# convert squad examples to features:  99%|█████████▊| 11713/11873 [00:53<00:00, 211.59it/s]
#
# convert squad examples to features:  99%|█████████▉| 11745/11873 [00:53<00:00, 225.02it/s]
#
# convert squad examples to features:  99%|█████████▉| 11777/11873 [00:53<00:00, 232.76it/s]
#
# convert squad examples to features:  99%|█████████▉| 11809/11873 [00:53<00:00, 246.54it/s]
#
# convert squad examples to features: 100%|██████████| 11873/11873 [00:53<00:00, 221.89it/s]
#
#
# add example index and unique id: 100%|██████████| 11873/11873 [00:00<00:00, 828960.47it/s]

# %%
dev_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=False)

# %%
import json
from datetime import datetime
from transformers.data.processors.squad import SquadFeatures
bs1 = bs1.to(device)
bs1.eval()

start_time = datetime.now()
outputs = dict()

for i, batch in enumerate(dev_loader):
    c_q_pairs = batch[0].to(device)
    attention_mask = batch[1].to(device)
    token_type_ids = batch[2].to(device)
    indices = bs1.predict(c_q_pairs, attention_mask, token_type_ids)
    start, end = indices[0][0], indices[0][1]
    tokens = tokenizer.convert_ids_to_tokens(c_q_pairs.view(-1).tolist())#[start:end+1])

    token_to_orig_map = features[i].token_to_orig_map
    if start in token_to_orig_map and end in token_to_orig_map:
        start, end = token_to_orig_map[start], token_to_orig_map[end]
        tokens = examples[features[i].example_index].doc_tokens[start:end+1] if start <= end else ""
        answer = ' '.join(tokens)
    else:
        answer = ""    
    

    if '<s>' in answer:
        answer = ""

    q_id = examples[features[i].example_index].qas_id
    if q_id not in outputs:
        outputs[examples[features[i].example_index].qas_id] = answer


    if i % 100 == 0:
        print('done with example : {}'.format(i))

print('total time for dev predictions : {}'.format(datetime.now() - start_time))
with open('roberta-dev-preds.json', 'w') as f:
    json.dump(outputs, f)
# Out:
# done with example : 0
# done with example : 100
# done with example : 200
# done with example : 300
# done with example : 400
# done with example : 500
# done with example : 600
# done with example : 700
# done with example : 800
# done with example : 900
# done with example : 1000
# done with example : 1100
# done with example : 1200
# done with example : 1300
# done with example : 1400
# done with example : 1500
# done with example : 1600
# done with example : 1700
# done with example : 1800
# done with example : 1900
# done with example : 2000
# done with example : 2100
# done with example : 2200
# done with example : 2300
# done with example : 2400
# done with example : 2500
# done with example : 2600
# done with example : 2700
# done with example : 2800
# done with example : 2900
# done with example : 3000
# done with example : 3100
# done with example : 3200
# done with example : 3300
# done with example : 3400
# done with example : 3500
# done with example : 3600
# done with example : 3700
# done with example : 3800
# done with example : 3900
# done with example : 4000
# done with example : 4100
# done with example : 4200
# done with example : 4300
# done with example : 4400
# done with example : 4500
# done with example : 4600
# done with example : 4700
# done with example : 4800
# done with example : 4900
# done with example : 5000
# done with example : 5100
# done with example : 5200
# done with example : 5300
# done with example : 5400
# done with example : 5500
# done with example : 5600
# done with example : 5700
# done with example : 5800
# done with example : 5900
# done with example : 6000
# done with example : 6100
# done with example : 6200
# done with example : 6300
# done with example : 6400
# done with example : 6500
# done with example : 6600
# done with example : 6700
# done with example : 6800
# done with example : 6900
# done with example : 7000
# done with example : 7100
# done with example : 7200
# done with example : 7300
# done with example : 7400
# done with example : 7500
# done with example : 7600
# done with example : 7700
# done with example : 7800
# done with example : 7900
# done with example : 8000
# done with example : 8100
# done with example : 8200
# done with example : 8300
# done with example : 8400
# done with example : 8500
# done with example : 8600
# done with example : 8700
# done with example : 8800
# done with example : 8900
# done with example : 9000
# done with example : 9100
# done with example : 9200
# done with example : 9300
# done with example : 9400
# done with example : 9500
# done with example : 9600
# done with example : 9700
# done with example : 9800
# done with example : 9900
# done with example : 10000
# done with example : 10100
# done with example : 10200
# done with example : 10300
# done with example : 10400
# done with example : 10500
# done with example : 10600
# done with example : 10700
# done with example : 10800
# done with example : 10900
# done with example : 11000
# done with example : 11100
# done with example : 11200
# done with example : 11300
# done with example : 11400
# done with example : 11500
# done with example : 11600
# done with example : 11700
# done with example : 11800
# done with example : 11900
# done with example : 12000
# done with example : 12100
# total time for dev predictions : 0:04:25.188492

# %% [markdown]
# # distilRoBERTa Model

# %%
import torch

from torch import nn
from transformers import RobertaModel, RobertaConfig, RobertaTokenizer

class DISTILROBERTA_SQUAD(nn.Module):
    def __init__(self):
        super(DISTILROBERTA_SQUAD, self).__init__()

        self.roberta_model = RobertaModel.from_pretrained('distilroberta-base')

        self.fc_layers = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        )

        self.criterion = nn.CrossEntropyLoss()



    def forward(self, c_q_pairs, attention_mask, token_type_ids, start_indices, end_indices):

        bert_encoded = self.roberta_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        start_indices = (start_indices).clamp(0, start_outputs.shape[1]-1)
        end_indices = (end_indices).clamp(0, start_outputs.shape[1]-1)

        start_loss = self.criterion(start_outputs, start_indices)
        end_loss = self.criterion(end_outputs, end_indices)

        return 2*start_loss + end_loss


    def predict(self, c_q_pairs, attention_mask, token_type_ids):
        bert_encoded = self.roberta_model(
            input_ids=c_q_pairs,
            attention_mask=attention_mask
        )[0]

        fc_output = self.fc_layers(bert_encoded)
        start_outputs, end_outputs = fc_output[:, :, 0].squeeze(-1), fc_output[:, :, 1].squeeze(-1)

        starts, s_ind = start_outputs.max(1)
        ends, e_ind = end_outputs.max(1)


        answers = []
        for i in range(start_outputs.shape[0]):
            start = s_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            end = e_ind[i].clamp(0, start_outputs.shape[1]-1).item()
            answers.append([start, end])
        return answers

# %%
tokenizer = RobertaTokenizer.from_pretrained('distilroberta-base')

# %%
bs1 = DISTILROBERTA_SQUAD()
bs1.load_state_dict(torch.load('/content/drive/My Drive/cis530project/distilroberta-squad.pt'))
# Out:
# <All keys matched successfully>

# %%
features, dataset = squad_convert_examples_to_features(
    examples=examples,
    tokenizer=tokenizer,
    max_seq_length=512,
    doc_stride=128,
    max_query_length=128,
    is_training=False,
    return_dataset='pt',
    threads=1
)
# Out:
# convert squad examples to features:   0%|          | 0/11873 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/11873 [00:00<36:33,  5.41it/s]
#
# convert squad examples to features:   0%|          | 33/11873 [00:00<25:45,  7.66it/s]
#
# convert squad examples to features:   1%|          | 65/11873 [00:00<18:15, 10.78it/s]
#
# convert squad examples to features:   1%|          | 97/11873 [00:00<13:00, 15.10it/s]
#
# convert squad examples to features:   1%|          | 129/11873 [00:00<09:17, 21.08it/s]
#
# convert squad examples to features:   1%|▏         | 161/11873 [00:00<06:39, 29.28it/s]
#
# convert squad examples to features:   2%|▏         | 193/11873 [00:00<04:52, 40.00it/s]
#
# convert squad examples to features:   2%|▏         | 225/11873 [00:01<03:37, 53.57it/s]
#
# convert squad examples to features:   2%|▏         | 257/11873 [00:01<02:43, 71.00it/s]
#
# convert squad examples to features:   2%|▏         | 289/11873 [00:01<02:06, 91.93it/s]
#
# convert squad examples to features:   3%|▎         | 321/11873 [00:01<01:40, 114.79it/s]
#
# convert squad examples to features:   3%|▎         | 353/11873 [00:01<01:21, 141.98it/s]
#
# convert squad examples to features:   4%|▎         | 417/11873 [00:01<01:07, 170.66it/s]
#
# convert squad examples to features:   4%|▍         | 449/11873 [00:01<00:57, 198.32it/s]
#
# convert squad examples to features:   4%|▍         | 481/11873 [00:01<00:53, 214.30it/s]
#
# convert squad examples to features:   4%|▍         | 513/11873 [00:02<00:51, 219.85it/s]
#
# convert squad examples to features:   5%|▍         | 545/11873 [00:02<00:49, 227.01it/s]
#
# convert squad examples to features:   5%|▌         | 609/11873 [00:02<00:44, 254.14it/s]
#
# convert squad examples to features:   5%|▌         | 641/11873 [00:02<00:42, 266.93it/s]
#
# convert squad examples to features:   6%|▌         | 673/11873 [00:02<00:42, 261.66it/s]
#
# convert squad examples to features:   6%|▌         | 705/11873 [00:02<00:42, 262.10it/s]
#
# convert squad examples to features:   6%|▌         | 737/11873 [00:02<00:44, 252.73it/s]
#
# convert squad examples to features:   7%|▋         | 801/11873 [00:03<00:39, 279.41it/s]
#
# convert squad examples to features:   7%|▋         | 865/11873 [00:03<00:35, 312.72it/s]
#
# convert squad examples to features:   8%|▊         | 929/11873 [00:03<00:31, 342.38it/s]
#
# convert squad examples to features:   8%|▊         | 966/11873 [00:03<00:34, 316.44it/s]
#
# convert squad examples to features:   8%|▊         | 1000/11873 [00:03<00:35, 308.46it/s]
#
# convert squad examples to features:   9%|▊         | 1033/11873 [00:03<00:36, 294.20it/s]
#
# convert squad examples to features:   9%|▉         | 1064/11873 [00:03<00:38, 277.18it/s]
#
# convert squad examples to features:   9%|▉         | 1093/11873 [00:03<00:45, 237.36it/s]
#
# convert squad examples to features:   9%|▉         | 1121/11873 [00:04<00:43, 245.64it/s]
#
# convert squad examples to features:  10%|▉         | 1153/11873 [00:04<00:43, 249.11it/s]
#
# convert squad examples to features:  84%|████████▎ | 9921/11873 [00:44<00:07, 259.22it/s]
#
# convert squad examples to features:  84%|████████▍ | 9953/11873 [00:44<00:07, 254.85it/s]
#
# convert squad examples to features:  84%|████████▍ | 9985/11873 [00:44<00:06, 271.25it/s]
#
# convert squad examples to features:  84%|████████▍ | 10017/11873 [00:44<00:06, 281.94it/s]
#
# convert squad examples to features:  85%|████████▍ | 10049/11873 [00:45<00:06, 282.22it/s]
#
# convert squad examples to features:  85%|████████▍ | 10081/11873 [00:45<00:06, 280.88it/s]
#
# convert squad examples to features:  85%|████████▌ | 10113/11873 [00:45<00:06, 281.53it/s]
#
# convert squad examples to features:  85%|████████▌ | 10145/11873 [00:45<00:06, 276.70it/s]
#
# convert squad examples to features:  86%|████████▌ | 10177/11873 [00:45<00:06, 244.36it/s]
#
# convert squad examples to features:  86%|████████▋ | 10241/11873 [00:45<00:06, 259.03it/s]
#
# convert squad examples to features:  87%|████████▋ | 10273/11873 [00:46<00:07, 209.35it/s]
#
# convert squad examples to features:  87%|████████▋ | 10305/11873 [00:46<00:06, 226.05it/s]
#
# convert squad examples to features:  87%|████████▋ | 10337/11873 [00:46<00:06, 231.83it/s]
#
# convert squad examples to features:  87%|████████▋ | 10369/11873 [00:46<00:06, 232.60it/s]
#
# convert squad examples to features:  88%|████████▊ | 10401/11873 [00:46<00:06, 218.49it/s]
#
# convert squad examples to features:  88%|████████▊ | 10433/11873 [00:46<00:06, 231.55it/s]
#
# convert squad examples to features:  88%|████████▊ | 10465/11873 [00:46<00:05, 242.84it/s]
#
# convert squad examples to features:  88%|████████▊ | 10497/11873 [00:46<00:05, 234.71it/s]
#
# convert squad examples to features:  89%|████████▊ | 10529/11873 [00:47<00:06, 204.14it/s]
#
# convert squad examples to features:  89%|████████▉ | 10561/11873 [00:47<00:06, 196.20it/s]
#
# convert squad examples to features:  89%|████████▉ | 10593/11873 [00:47<00:06, 207.23it/s]
#
# convert squad examples to features:  89%|████████▉ | 10625/11873 [00:47<00:06, 188.97it/s]
#
# convert squad examples to features:  90%|████████▉ | 10657/11873 [00:47<00:05, 203.94it/s]
#
# convert squad examples to features:  90%|█████████ | 10689/11873 [00:47<00:05, 215.27it/s]
#
# convert squad examples to features:  90%|█████████ | 10721/11873 [00:48<00:05, 224.10it/s]
#
# convert squad examples to features:  91%|█████████ | 10753/11873 [00:48<00:04, 229.79it/s]
#
# convert squad examples to features:  91%|█████████ | 10785/11873 [00:48<00:04, 228.70it/s]
#
# convert squad examples to features:  91%|█████████ | 10817/11873 [00:48<00:05, 207.02it/s]
#
# convert squad examples to features:  91%|█████████▏| 10849/11873 [00:48<00:04, 216.31it/s]
#
# convert squad examples to features:  92%|█████████▏| 10881/11873 [00:48<00:04, 224.01it/s]
#
# convert squad examples to features:  92%|█████████▏| 10913/11873 [00:48<00:04, 223.70it/s]
#
# convert squad examples to features:  92%|█████████▏| 10945/11873 [00:49<00:03, 238.88it/s]
#
# convert squad examples to features:  92%|█████████▏| 10977/11873 [00:49<00:03, 254.20it/s]
#
# convert squad examples to features:  93%|█████████▎| 11009/11873 [00:49<00:03, 249.38it/s]
#
# convert squad examples to features:  93%|█████████▎| 11041/11873 [00:49<00:03, 262.98it/s]
#
# convert squad examples to features:  93%|█████████▎| 11073/11873 [00:49<00:03, 264.05it/s]
#
# convert squad examples to features:  94%|█████████▎| 11105/11873 [00:49<00:03, 249.28it/s]
#
# convert squad examples to features:  94%|█████████▍| 11137/11873 [00:49<00:02, 251.50it/s]
#
# convert squad examples to features:  94%|█████████▍| 11169/11873 [00:49<00:02, 247.66it/s]
#
# convert squad examples to features:  94%|█████████▍| 11201/11873 [00:50<00:02, 241.28it/s]
#
# convert squad examples to features:  95%|█████████▍| 11233/11873 [00:50<00:02, 226.05it/s]
#
# convert squad examples to features:  95%|█████████▍| 11265/11873 [00:50<00:02, 233.00it/s]
#
# convert squad examples to features:  95%|█████████▌| 11297/11873 [00:50<00:02, 236.24it/s]
#
# convert squad examples to features:  95%|█████████▌| 11329/11873 [00:50<00:02, 228.61it/s]
#
# convert squad examples to features:  96%|█████████▌| 11361/11873 [00:50<00:02, 231.38it/s]
#
# convert squad examples to features:  96%|█████████▌| 11393/11873 [00:50<00:02, 225.83it/s]
#
# convert squad examples to features:  96%|█████████▌| 11425/11873 [00:51<00:01, 245.37it/s]
#
# convert squad examples to features:  96%|█████████▋| 11457/11873 [00:51<00:01, 232.12it/s]
#
# convert squad examples to features:  97%|█████████▋| 11489/11873 [00:51<00:01, 223.03it/s]
#
# convert squad examples to features:  97%|█████████▋| 11521/11873 [00:51<00:01, 210.93it/s]
#
# convert squad examples to features:  97%|█████████▋| 11553/11873 [00:51<00:01, 221.89it/s]
#
# convert squad examples to features:  98%|█████████▊| 11585/11873 [00:51<00:01, 214.41it/s]
#
# convert squad examples to features:  98%|█████████▊| 11617/11873 [00:51<00:01, 216.92it/s]
#
# convert squad examples to features:  98%|█████████▊| 11649/11873 [00:52<00:01, 206.64it/s]
#
# convert squad examples to features:  98%|█████████▊| 11681/11873 [00:52<00:00, 204.84it/s]
#
# convert squad examples to features:  99%|█████████▊| 11713/11873 [00:52<00:00, 212.48it/s]
#
# convert squad examples to features:  99%|█████████▉| 11745/11873 [00:52<00:00, 229.05it/s]
#
# convert squad examples to features:  99%|█████████▉| 11777/11873 [00:52<00:00, 236.80it/s]
#
# convert squad examples to features:  99%|█████████▉| 11809/11873 [00:52<00:00, 251.78it/s]
#
# convert squad examples to features: 100%|██████████| 11873/11873 [00:52<00:00, 224.44it/s]
#
#
# add example index and unique id: 100%|██████████| 11873/11873 [00:00<00:00, 853379.68it/s]

# %%
dev_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=False)

# %%
import json
from datetime import datetime
from transformers.data.processors.squad import SquadFeatures
bs1 = bs1.to(device)
bs1.eval()

start_time = datetime.now()
outputs = dict()

for i, batch in enumerate(dev_loader):
    c_q_pairs = batch[0].to(device)
    attention_mask = batch[1].to(device)
    token_type_ids = batch[2].to(device)
    indices = bs1.predict(c_q_pairs, attention_mask, token_type_ids)
    start, end = indices[0][0], indices[0][1]
    tokens = tokenizer.convert_ids_to_tokens(c_q_pairs.view(-1).tolist())#[start:end+1])

    token_to_orig_map = features[i].token_to_orig_map
    if start in token_to_orig_map and end in token_to_orig_map:
        start, end = token_to_orig_map[start], token_to_orig_map[end]
        tokens = examples[features[i].example_index].doc_tokens[start:end+1] if start <= end else ""
        answer = ' '.join(tokens)
    else:
        answer = ""    
    

    if '<s>' in answer:
        answer = ""

    q_id = examples[features[i].example_index].qas_id
    if q_id not in outputs:
        outputs[examples[features[i].example_index].qas_id] = answer


    if i % 100 == 0:
        print('done with example : {}'.format(i))

print('total time for dev predictions : {}'.format(datetime.now() - start_time))
with open('distilroberta-dev-preds.json', 'w') as f:
    json.dump(outputs, f)
# Out:
# done with example : 0
# done with example : 100
# done with example : 200
# done with example : 300
# done with example : 400
# done with example : 500
# done with example : 600
# done with example : 700
# done with example : 800
# done with example : 900
# done with example : 1000
# done with example : 1100
# done with example : 1200
# done with example : 1300
# done with example : 1400
# done with example : 1500
# done with example : 1600
# done with example : 1700
# done with example : 1800
# done with example : 1900
# done with example : 2000
# done with example : 2100
# done with example : 2200
# done with example : 2300
# done with example : 2400
# done with example : 2500
# done with example : 2600
# done with example : 2700
# done with example : 2800
# done with example : 2900
# done with example : 3000
# done with example : 3100
# done with example : 3200
# done with example : 3300
# done with example : 3400
# done with example : 3500
# done with example : 3600
# done with example : 3700
# done with example : 3800
# done with example : 3900
# done with example : 4000
# done with example : 4100
# done with example : 4200
# done with example : 4300
# done with example : 4400
# done with example : 4500
# done with example : 4600
# done with example : 4700
# done with example : 4800
# done with example : 4900
# done with example : 5000
# done with example : 5100
# done with example : 5200
# done with example : 5300
# done with example : 5400
# done with example : 5500
# done with example : 5600
# done with example : 5700
# done with example : 5800
# done with example : 5900
# done with example : 6000
# done with example : 6100
# done with example : 6200
# done with example : 6300
# done with example : 6400
# done with example : 6500
# done with example : 6600
# done with example : 6700
# done with example : 6800
# done with example : 6900
# done with example : 7000
# done with example : 7100
# done with example : 7200
# done with example : 7300
# done with example : 7400
# done with example : 7500
# done with example : 7600
# done with example : 7700
# done with example : 7800
# done with example : 7900
# done with example : 8000
# done with example : 8100
# done with example : 8200
# done with example : 8300
# done with example : 8400
# done with example : 8500
# done with example : 8600
# done with example : 8700
# done with example : 8800
# done with example : 8900
# done with example : 9000
# done with example : 9100
# done with example : 9200
# done with example : 9300
# done with example : 9400
# done with example : 9500
# done with example : 9600
# done with example : 9700
# done with example : 9800
# done with example : 9900
# done with example : 10000
# done with example : 10100
# done with example : 10200
# done with example : 10300
# done with example : 10400
# done with example : 10500
# done with example : 10600
# done with example : 10700
# done with example : 10800
# done with example : 10900
# done with example : 11000
# done with example : 11100
# done with example : 11200
# done with example : 11300
# done with example : 11400
# done with example : 11500
# done with example : 11600
# done with example : 11700
# done with example : 11800
# done with example : 11900
# done with example : 12000
# done with example : 12100
# total time for dev predictions : 0:02:20.096197
